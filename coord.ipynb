# %% [markdown]
# <a href="https://colab.research.google.com/github/theethatp/cars/blob/master/coord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('BangPo_UpRight.csv')

# %%
df.head()
# Out:
#   loc_id  ... Unnamed: 6
# 0  ลำดับ  ...        NaN
# 1      1  ...        NaN
# 2      2  ...        NaN
# 3      3  ...        NaN
# 4      4  ...        NaN
#
# [5 rows x 7 columns]

# %%
sr_df=df.loc[:,'(lat,lon)']

# %%
sr_df
# Out:
# 0                                                จุดมุม
# 1     (13.806724, 100.521651),(13.806446, 100.521639...
# 2     (13.806727, 100.523683),(13.806495, 100.523686...
# 3     (13.806722, 100.524743),(13.806464, 100.524724...
# 4     (13.807502, 100.521708),(13.806776, 100.521678...
#                             ...
# 64    (13.810298386095244, 100.52186488639829),(13.8...
# 65    (13.810757832411422, 100.52190228109218),(13.8...
# 66    (13.810334699757197, 100.5222046903414),(13.81...
# 67    (13.81037101341204, 100.52267781448079),(13.81...
# 68    (13.810751517005116, 100.52217542491819),(13.8...
# Name: (lat,lon), Length: 69, dtype: object

# %%
type(sr_df)
# Out:
# pandas.core.series.Series

# %%
l=[]
for index,value in sr_df.items():
  l.append(value)

# %%
l.pop(0)
# Out:
# []

# %%
l
# Out:
# ['(13.806724, 100.521651),(13.806446, 100.521639),(13.806498, 100.523627),(13.806722, 100.523629)',
#  '(13.806727, 100.523683),(13.806495, 100.523686),(13.806463, 100.524693),(13.806730, 100.524703)',
#  '(13.806722, 100.524743),(13.806464, 100.524724),(13.806485, 100.526082),(13.806727, 100.526099)',
#  '(13.807502, 100.521708),(13.806776, 100.521678),(13.806797, 100.522353),(13.807506, 100.522392)',
#  '(13.807191, 100.522428),(13.806790, 100.522401),(13.806785, 100.523624),(13.807136, 100.523619)',
#  '(13.807146, 100.523667),(13.806953, 100.523678),(13.806949, 100.524702),(13.807135, 100.524711)',
#  '(13.806940, 100.523677),(13.806770, 100.523675),(13.806768, 100.524696),(13.806953, 100.524704)',
#  '(13.807133, 100.524754),(13.806892, 100.524751),(13.806886, 100.524876),(13.807134, 100.524891)',
#  '(13.806879, 100.524750),(13.806770, 100.524744),(13.806768, 100.524967),(13.806879, 100.524964)',
# ...

# %%
coor =[]
for i in
# Out:
# 68
